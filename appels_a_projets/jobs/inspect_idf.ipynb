# %%
import requests
import pandas as pd

# %%
API_URL = "https://data.iledefrance.fr/api/records/1.0/search/"

params = {
    "dataset": "aides-appels-a-projets",
    "rows": 50,      
    "start": 0       
}

r = requests.get(API_URL, params=params, timeout=30)
r.raise_for_status()

data = r.json()

data
# Out:
# {'nhits': 343,
#  'parameters': {'dataset': 'aides-appels-a-projets',
#   'rows': 50,
#   'start': 0,
#   'format': 'json',
#   'timezone': 'UTC'},
#  'records': [{'datasetid': 'aides-appels-a-projets',
#    'recordid': 'db22f057f603f4142f40ea44dd5d2a9f1a117ba7',
#    'fields': {'qui_peut_en_beneficier': "Établissement d'enseignement supérieur",
#     'chapo_txt': "La Région entend, via ces distinctions, permettre aux établissements d'enseignement supérieur de déployer des outils adaptés à la variété des profils de leurs étudiants et à la diversité de leurs territoires.",
#     'id_theme': '130',
#     'porteur_aide': 'Région Île-de-France',
#     'id_aide': 'rkOFGrVla',
#     'id_publics': '211',
#     'presence_ref': 'False',
#     'qui': "Établissement d'enseignement supérieur",
# ...

# %%
rows = []
for rec in data["records"]:
    row = rec["fields"].copy()
    row["_recordid"] = rec["recordid"]
    row["_record_timestamp"] = rec["record_timestamp"]
    row["_record_url"] = rec.get("record_url")
    rows.append(row)

df = pd.DataFrame(rows)
df.shape
# Out:
# (50, 39)

# %%
df
# Out:
#                                qui_peut_en_beneficier  \
# 0              Établissement d'enseignement supérieur
# 1   Association - Fondation|||Association - ONG|||...
# 2   Collectivité ou institution - Communes de 10 0...
# 3                                         Entreprises
# 4   Particulier - Lycéen|||Établissement d'enseign...
# 5   Associations|||Collectivités - Institutions|||...
# 6   Professionnel - Chercheur|||Établissement de r...
# 7   Établissement de recherche et laboratoire|||Pr...
# 8   Collectivité ou institution - Communes de < 20...
# 9   Professionnel - TPE < 10|||Professionnel - PME...
# 10  Collectivité ou institution - Autre (GIP, copr...
# 11  Professionnel - Agriculture et alimentation|||...
# 12  Établissement d'enseignement secondaire|||Part...
# 13  Collectivité ou institution - Communes de 10 0...
# 14  Association - Fondation|||Association - ONG|||...
# 15                         Entreprises|||Associations
# ...

# %%
# Voir les colonnes disponibles
print("Colonnes disponibles:")
for col in df.columns:
    non_null = df[col].notna().sum()
    print(f"  - {col}: {non_null}/50")
# Out:
# Colonnes disponibles:
#   - qui_peut_en_beneficier: 50/50
#   - chapo_txt: 50/50
#   - id_theme: 50/50
#   - porteur_aide: 50/50
#   - id_aide: 50/50
#   - id_publics: 50/50
#   - presence_ref: 50/50
#   - qui: 50/50
#   - entete: 50/50
#   - modalite_txt: 50/50
#   - competences: 50/50
#   - demarches: 50/50
#   - demarches_txt: 50/50
#   - date_cloture: 33/50
#   - mots_cles: 38/50
#   - nom_de_l_aide_de_la_demarche: 50/50
#   - recup_id_thm: 49/50
#   - porteur_siren: 50/50
#   - objectif: 50/50
#   - url_descriptif: 50/50
#   - publicsbeneficiaireprecision: 46/50
#   - theme: 50/50
#   - demarche_en_ligne: 50/50
#   - objectif_txt: 50/50
#   - modalite: 50/50
#   - reference_administrative: 50/50
#   - date_ouverture: 33/50
#   - date: 50/50
#   - _recordid: 50/50
#   - _record_timestamp: 50/50
#   - _record_url: 0/50
#   - notes_txt: 29/50
#   - deliberation_cadre: 32/50
#   - engagements_du_beneficiaire: 28/50
#   - notes: 30/50
#   - contact: 46/50
# ...

# %%
# Voir un exemple complet
sample = df.iloc[0].dropna().to_dict()
for k, v in sample.items():
    val = str(v)[:200] + "..." if len(str(v)) > 200 else v
    print(f"{k}: {val}\n")
# Out:
# qui_peut_en_beneficier: Établissement d'enseignement supérieur
#
# chapo_txt: La Région entend, via ces distinctions, permettre aux établissements d'enseignement supérieur de déployer des outils adaptés à la variété des profils de leurs étudiants et à la diversité de leurs terr...
#
# id_theme: 130
#
# porteur_aide: Région Île-de-France
#
# id_aide: rkOFGrVla
#
# id_publics: 211
#
# presence_ref: False
#
# qui: Établissement d'enseignement supérieur
#
# entete: La R&eacute;gion entend, via ces distinctions, permettre aux &eacute;tablissements d'enseignement sup&eacute;rieur de d&eacute;ployer des outils adapt&eacute;s &agrave; la vari&eacute;t&eacute; des pr...
#
# modalite_txt: Les projets présentés par un établissement ou un groupement
# d'enseignement supérieur et de recherche, conçus avec au moins 1 prestataire (ou partenaire) extérieur à l'établissement, localisés dans 1 ...
#
# ...

# %%
# Comparaison des champs disponibles entre Carenews et IDF
import json

print("=" * 60)
print("COMPARAISON DES SOURCES")
print("=" * 60)

# Carenews
with open("../../data/carenews_raw.json") as f:
    carenews = json.load(f)

# IDF
with open("../../data/iledefrance_raw.json") as f:
    idf = json.load(f)

print(f"\n📊 Carenews: {len(carenews)} AAPs")
print(f"📊 IDF OpenData: {len(idf)} AAPs")

print("\n" + "-" * 60)
print("Champs communs (spécification)")
print("-" * 60)

spec_fields = [
    "titre", "organisme", "date_publication", "date_limite",
    "url_source", "resume", "categories", "tags", 
    "public_cible", "perimetre_geo", "montant_min", "montant_max"
]

for field in spec_fields:
    cn_count = sum(1 for d in carenews if d.get(field)) if carenews else 0
    idf_count = sum(1 for d in idf if d.get(field)) if idf else 0
    cn_pct = f"{cn_count}/{len(carenews)}" if carenews else "N/A"
    idf_pct = f"{idf_count}/{len(idf)}" if idf else "N/A"
    print(f"  {field:20} | Carenews: {cn_pct:10} | IDF: {idf_pct:10}")
# Out:
# ...
# COMPARAISON DES SOURCES
# ...
#
# 📊 Carenews: 40 AAPs
# 📊 IDF OpenData: 100 AAPs
#
# ------------------------------------------------------------
# Champs communs (spécification)
# ------------------------------------------------------------
#   titre                | Carenews: 40/40      | IDF: 100/100
#   organisme            | Carenews: 17/40      | IDF: 100/100
#   date_publication     | Carenews: 40/40      | IDF: 73/100
#   date_limite          | Carenews: 40/40      | IDF: 64/100
#   url_source           | Carenews: 40/40      | IDF: 100/100
#   resume               | Carenews: 40/40      | IDF: 100/100
#   categories           | Carenews: 0/40       | IDF: 100/100
#   tags                 | Carenews: 0/40       | IDF: 68/100
#   public_cible         | Carenews: 0/40       | IDF: 100/100
#   perimetre_geo        | Carenews: 0/40       | IDF: 100/100
#   montant_min          | Carenews: 0/40       | IDF: 0/100
#   montant_max          | Carenews: 0/40       | IDF: 0/100
